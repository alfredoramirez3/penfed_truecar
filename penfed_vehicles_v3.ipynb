# %%
import ipywidgets as widgets
from IPython.display import display

import glob2
import pandas as pd

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 100) #50) # default

# %%
def update_make_model(make_model):
    global filepath
    filepath = './output/*{}*.csv'.format(make_model)
    print(filepath)
    return None

make_models = ['Mazda-Miata', 'BMW-Z4', 'Nissan-370Z', 'Toyota-4Runner']
drop_down = \
widgets.Dropdown(
    options = make_models,
    value = make_models[0],
    description = 'Select Make-Model',
    disabled=False,
)

#display(drop_down)
widgets.interactive(update_make_model, make_model=drop_down)
# Out:
# interactive(children=(Dropdown(description='Select Make-Model', options=('Mazda-Miata', 'BMW-Z4', 'Nissan-370Z…

# %%
filenames = glob2.glob(filepath)
#print(filenames)

# %%
df = pd.read_csv(filenames[0])
for filename in filenames[1:]:
    df = pd.concat([df, pd.read_csv(filename)], ignore_index=True, sort=False)

# %%
df.index.name = 'orig_index'

# %%
#df.head(2)

# %%
agg = df.groupby('vin').agg({'date': ['max', 'min', 'count']})
agg.columns = ['max_date', 'min_date', 'count_date']

# add aggregations to row by vin
df_stats = df.join(agg, on='vin')

# %%
#df_stats.head(2)

# %%
def avail(row, date_max):
    if row['count_date'] == 1 and row['date'] == date_max:
        return 'new listing'
    if row['max_date'] < date_max:
        return 'listing not avail'
    return 'listing avail'

date_max = df['date'].max()
date_max

df_stats['availability'] = df_stats.apply(avail, axis=1, date_max=date_max)

# %%
#df_stats.head(2)

# %%
# order rows by vin and date to setup for calculating the price difference between dates
df_stats = df_stats.sort_values(by=['vin', 'date'])

# %%
#df_stats.head(15)

# %%
df_stats_price_diff = df_stats.groupby('vin')['vehicle_price'].rolling(2).apply(lambda price: price[1] - price[0], raw=True).to_frame('price_diff').reset_index()

# %%
#df_stats_price_diff.head(5)

# %%
assert len(df_stats) == len(df_stats_price_diff)

# %%
# join(..., left_on='index', right_on='level_1') is sufficient
# adding 'vin' is redundant, but keeps from adding duplicate columns vin_x, vin_y to dataframe
df_stats = df_stats.merge(df_stats_price_diff, left_on=['vin', 'orig_index'], right_on=['vin', 'orig_index'])

# %%
#df_stats.head(5)

# %%
#df_stats.columns

# %%
#['year_make_model_1', ''index', detail_url', 'vin', 'price_rating', 'vehicle_price', 'year_make_model_2', 'trim', 'location', 'mileage', 'exterior_color',
# 'interior_color', 'mpg', 'engine', 'transmission', 'drive_type', 'fuel_type', 'accident_check', 'usage', 'title', 'number_of_owners', 'date', 'max_date', 'min_date', 
# 'count_date', 'availability', 'price_diff']

# columns wanted for analysis
df_less_columns = df_stats[['year_make_model_1', 'vin', 'price_rating', 'vehicle_price', 'price_diff', 'trim', 'location', 'mileage', 
                 'exterior_color', 'interior_color', 'transmission', 'accident_check', 'usage', 'title', 'number_of_owners', 'date', 'availability', 'detail_url']]

# %%
#df_less_columns.head(5)

# %%
# various row filters
filter1 = df_less_columns['accident_check'] == 0 # no accidents
filter2 = df_less_columns['number_of_owners'] < 3 # less than three owners
filter3 = df_less_columns['title'] == 'Clean' # only interested in clean titles
filter4 = df_less_columns['availability'] != 'listing not avail' # not interested in listings that are no longer available

# %%
# note, for very large datasets it would be better to save new dataframe with the applied filter(s) instead of repeated filtering

#df_less_columns[filter1
#df_less_columns[filter1 & filter2]
#df_less_columns[filter1 & filter2 & filter3]
vins = list(set(df_less_columns[filter1 & filter2 & filter3 & filter4]['vin']))
list(enumerate(vins))
# Out:
# [(0, 'JTEBU5JR2C5108050'),
#  (1, 'JTEBU5JR4B5064969'),
#  (2, 'JTEBU5JR7A5010385'),
#  (3, 'JTEBU5JR1C5109657'),
#  (4, 'JTEBU5JR9E5195657'),
#  (5, 'JTEBU5JR2A5010715'),
#  (6, 'JTEBU5JR1E5186516'),
#  (7, 'JTEBU5JR2D5131684'),
#  (8, 'JTEBU5JR9F5213933'),
#  (9, 'JTEBU5JR1D5118747'),
#  (10, 'JTEBU5JR7D5129218'),
#  (11, 'JTEBU5JR0A5015377'),
#  (12, 'JTEBU5JR4B5071033')]

# %%
def update_vin(vin):
    #print('create dataframe for {} csv files'.format(make_model))
    global sel_vin
    sel_vin = vin
    #print(sel_vin)
    return None

vins = list(set(df_less_columns[filter1 & filter2 & filter3 & filter4]['vin']))
drop_down = \
widgets.Dropdown(
    options = vins,
    value = vins[0],
    description = 'Select vins',
    disabled=False,
)

#display(drop_down)
widgets.interactive(update_vin, vin=drop_down)
# Out:
# interactive(children=(Dropdown(description='Select vins', options=('JTEBU5JR2C5108050', 'JTEBU5JR4B5064969', '…

# %%
filter5 = df_less_columns['vin'] == sel_vin
df_less_columns[filter5] #['detail_url']
# Out:
#        year_make_model_1                vin     price_rating  vehicle_price  \
# 191  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 192  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 193  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 194  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 195  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 196  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 197  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 198  2012 Toyota 4Runner  JTEBU5JR2C5108050  Excellent Price          18250
# 199  2012 Toyota 4Runner  JTEBU5JR2C5108050  Excellent Price          18250
# 200  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 201  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 202  2012 Toyota 4Runner  JTEBU5JR2C5108050  Excellent Price          18250
# 203  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 204  2012 Toyota 4Runner  JTEBU5JR2C5108050  Excellent Price          18250
# 205  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18250
# 206  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 207  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 208  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 209  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 210  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 211  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 212  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          18000
# 213  2012 Toyota 4Runner  JTEBU5JR2C5108050      Great Price          17500
# 214  2012 Toyota 4Runner  JTEBU5JR2C5108050  Excellent Price          17500
# 215  2012 Toyota 4Runner  JTEBU5JR2C5108050  Excellent Price          17500
#
#      price_diff        trim     location  mileage           exterior_color  \
# 191         NaN  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 192         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 193         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 194         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 195         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 196         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 197         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 198         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 199         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 200         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 201         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 202         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 203         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 204         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 205         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 206      -250.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 207         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 208         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 209         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 210         0.0  SR5 V6 4WD  Seekonk, MA    91294  Classic Silver Metallic
# 211         0.0  SR5 V6 4WD  Seekonk, MA    91295  Classic Silver Metallic
# 212         0.0  SR5 V6 4WD  Seekonk, MA    91295  Classic Silver Metallic
# 213      -500.0  SR5 V6 4WD  Seekonk, MA    91295  Classic Silver Metallic
# 214         0.0  SR5 V6 4WD  Seekonk, MA    91295  Classic Silver Metallic
# 215         0.0  SR5 V6 4WD  Seekonk, MA    91295  Classic Silver Metallic
#
#      interior_color transmission  accident_check                   usage  \
# 191  Black/Graphite    Automatic               0  Personal or Rental Use
# 192  Black/Graphite    Automatic               0  Personal or Rental Use
# 193  Black/Graphite    Automatic               0  Personal or Rental Use
# 194  Black/Graphite    Automatic               0  Personal or Rental Use
# 195  Black/Graphite    Automatic               0  Personal or Rental Use
# 196  Black/Graphite    Automatic               0  Personal or Rental Use
# 197  Black/Graphite    Automatic               0  Personal or Rental Use
# 198  Black/Graphite    Automatic               0  Personal or Rental Use
# 199  Black/Graphite    Automatic               0  Personal or Rental Use
# 200  Black/Graphite    Automatic               0  Personal or Rental Use
# 201  Black/Graphite    Automatic               0  Personal or Rental Use
# 202  Black/Graphite    Automatic               0  Personal or Rental Use
# 203  Black/Graphite    Automatic               0  Personal or Rental Use
# 204  Black/Graphite    Automatic               0  Personal or Rental Use
# 205  Black/Graphite    Automatic               0  Personal or Rental Use
# 206  Black/Graphite    Automatic               0  Personal or Rental Use
# 207  Black/Graphite    Automatic               0  Personal or Rental Use
# 208  Black/Graphite    Automatic               0  Personal or Rental Use
# 209  Black/Graphite    Automatic               0  Personal or Rental Use
# 210  Black/Graphite    Automatic               0  Personal or Rental Use
# 211  Black/Graphite    Automatic               0  Personal or Rental Use
# 212  Black/Graphite    Automatic               0  Personal or Rental Use
# 213  Black/Graphite    Automatic               0  Personal or Rental Use
# 214  Black/Graphite    Automatic               0  Personal or Rental Use
# 215  Black/Graphite    Automatic               0  Personal or Rental Use
#
#      title  number_of_owners                        date   availability  \
# 191  Clean                 2  2020-03-13 08:25:29.186547  listing avail
# 192  Clean                 2  2020-03-14 06:56:26.527273  listing avail
# 193  Clean                 2  2020-03-16 07:36:38.804909  listing avail
# 194  Clean                 2  2020-03-16 20:15:13.448345  listing avail
# 195  Clean                 2  2020-03-17 09:57:02.609133  listing avail
# 196  Clean                 2  2020-03-18 10:00:03.205843  listing avail
# 197  Clean                 2  2020-03-21 09:59:35.636160  listing avail
# 198  Clean                 2  2020-03-23 18:45:13.538394  listing avail
# 199  Clean                 2  2020-03-25 08:18:41.949178  listing avail
# 200  Clean                 2  2020-03-29 20:03:24.703305  listing avail
# 201  Clean                 2  2020-03-30 07:12:10.535293  listing avail
# 202  Clean                 2  2020-03-31 09:50:21.519723  listing avail
# 203  Clean                 2  2020-04-01 09:37:31.230898  listing avail
# 204  Clean                 2  2020-04-02 16:08:46.120833  listing avail
# 205  Clean                 2  2020-04-07 13:18:52.333425  listing avail
# 206  Clean                 2  2020-04-10 10:32:43.584011  listing avail
# 207  Clean                 2  2020-04-14 08:16:00.431782  listing avail
# 208  Clean                 2  2020-04-19 09:56:01.391770  listing avail
# 209  Clean                 2  2020-04-21 10:50:13.109397  listing avail
# 210  Clean                 2  2020-04-22 11:38:17.289109  listing avail
# 211  Clean                 2  2020-04-24 10:41:47.922076  listing avail
# 212  Clean                 2  2020-04-25 10:54:29.302753  listing avail
# 213  Clean                 2  2020-04-29 13:34:13.975873  listing avail
# 214  Clean                 2  2020-04-30 08:41:53.537198  listing avail
# 215  Clean                 2  2020-05-07 10:58:31.893491  listing avail
#
#                                                                                        detail_url
# 191  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 192  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 193  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 194  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 195  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 196  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 197  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 198  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 199  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 200  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 201  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 202  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 203  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 204  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 205  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 206  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 207  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 208  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 209  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 210  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 211  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 212  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 213  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 214  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/
# 215  https://penfed.truecar.com/used-cars-for-sale/listing/JTEBU5JR2C5108050/2012-toyota-4runner/

# %%
# filter by index range
#df_less_columns[filter1 & filter2 & filter3 & filter4].loc[66:79] # view range of listings of interest

# %%
# filter by index row
#df_less_columns[filter1 & filter2 & filter3 & filter4].loc[109] # view listings details for a specific listing
